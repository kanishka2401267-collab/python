# %%
tuple=("kanishka",1)
print(tuple)
# Out:
# ('kanishka', 1)

# %%
empty_tuple=()
print(empty_tuple)
# Out:
# ()

# %%
tuple="kani",10,30,3.67
print(tuple)
# Out:
# ('kani', 10, 30, 3.67)

# %%
tuple=10,20,40,50,20,"moon"
print(type(tuple))
# Out:
# <class 'tuple'>

# %%
tuple="kanishka"
print(type(tuple))
# Out:
# <class 'str'>

# %%
tuple=('k',1,2,3,4,5,76)
t=tuple[-1]
print(t)
# Out:
# 76

# %%
tuple=(1,2,3,4,5,67)
t=tuple[-3]
print(t)
# Out:
# 4

# %%
tuple=(1,3,5,7,0)
t=tuple[-3:-1]
print(t)
# Out:
# (5, 7)

# %%
tuple=1,2,3,4,5
t=tuple[-4:-1]
print(t)
# Out:
# (2, 3, 4)

# %%
tuple=1,2,23,45,67,2
res=tuple.count(2)
print(res)
# Out:
# 2

# %%
tuple="computer","system","one","two","three"
res=tuple.count("three")
print(res)
# Out:
# 1

# %%
tuple=(1,2,3,43,55,67,78,989)
res=tuple.index(55)
print(res)
# Out:
# 4

# %%
tuple_=1,2,3,4,5,6,7,8,9,0
for i in tuple_ :
   print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 0

# %%
tuple_=1,2,3,4,5,6,7,8,9,0
print(1 in tuple_)
print(1 not in tuple_)
# Out:
# True
# False

# %%
tuple="kanishka","subha","sangee","jay","jan"
print("subha" in tuple)
print("sangee" in tuple)
# Out:
# True
# True

# %%
tuple=1,2,3,4,1,2,3,4,2
print(tuple.index(2,2))
# Out:
# 5

# %%
tuple="kanishka","jan","subha","sangee","jay"
print(tuple_+("shree" , ))
# Out:
# ('kanishka', 'subha', 'sangee', 'jay', 'jan', 'shree')

# %%
print("assignment tuple")
# Out:
# assignment tuple

# %%
tuple=("soap", 40, "shampoo", 4,"bag",2500,"soap")
print("a)")
print(tuple[0])
print(tuple[1])
print(tuple[2])
print(tuple[3])
print(tuple[4])
print("b)")
tuple1=tuple.count("soap")
print(tuple1)
print("c)")
product_name="bag"
result=tuple.index(product_name)
print(result)
print("d)")
t=tuple[-3:-1]
print("the rate of a product and its rate:",t )
print("e)")
list1= __builtins__.list(tuple)
print(list1)
list1[0]="toothpaste"
tuple=__builtins__.tuple(list1)
print(tuple)
# Out:
# a)
# soap
# 40
# shampoo
# 4
# bag
# b)
# 2
# c)
# 4
# d)
# the rate of a product and its rate: ('bag', 2500)
# e)
# ['soap', 40, 'shampoo', 4, 'bag', 2500, 'soap']
# ('toothpaste', 40, 'shampoo', 4, 'bag', 2500, 'soap')
